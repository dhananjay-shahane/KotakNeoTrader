# %%
# ============================================================================
# CELL 2: Import Required Libraries
# ============================================================================

import pandas as pd
import json
import time
from datetime import datetime
import warnings
warnings.filterwarnings('ignore')

# Import Kotak Neo API client
from neo_api_client import NeoAPI
from neo_api_client import BaseUrl

print("Libraries imported successfully!")
print("Kotak Neo API Client v2.0.0 ready to use")
# Out:
# Libraries imported successfully!
# Kotak Neo API Client v2.0.0 ready to use

# %%
# ============================================================================
# CELL 3: Configuration - Update Your Credentials
# ============================================================================

# ⚠️ IMPORTANT: Update these credentials with your actual details
# You can get these from your Kotak Securities account

# Your Kotak Neo credentials
MOBILE_NUMBER = "+919372209322"  # Your registered mobile number
UCC = "ZHZ3J"  # Unique Client Code from your profile
CONSUMER_KEY = "4OKP7bOfI5ozzCB1EI4a6DOIyJsa"  # From API registration
CONSUMER_SECRET = "cnLm3ZSJVLCOPiwTk4xAJw5G8v0a"  # From API registration
NEO_FIN_KEY = "neotradeapi"  # Key received at API registration
MPIN = "484848"  # Your MPIN

# Environment settings
ENVIRONMENT = "prod"  # Use "uat" for testing, "prod" for live trading

# %%
# ============================================================================
# CELL 4: Initialize API Client
# ============================================================================

def initialize_neo_client():
    """Initialize the Kotak Neo API client"""
    try:
        # Get base URL
        base_url = BaseUrl(ucc=UCC).get_base_url()
        print(f"Base URL retrieved: {base_url}")
        
        # Initialize client
        client = NeoAPI(
            consumer_key=CONSUMER_KEY,
            consumer_secret=CONSUMER_SECRET,
            environment=ENVIRONMENT,
            access_token=None,
            neo_fin_key=NEO_FIN_KEY,
            base_url=base_url
        )
        
        print("✅ Neo API client initialized successfully!")
        return client
        
    except Exception as e:
        print(f"❌ Error initializing Neo API client: {str(e)}")
        return None

# Initialize the client
client = initialize_neo_client()
# Out:
# https://gw-napi.kotaksecurities.com/
# Base URL retrieved: https://gw-napi.kotaksecurities.com/
# ...

# %%
# ============================================================================
# CELL 5: Login Functions
# ============================================================================

def login_with_totp(client, mobile_number, ucc, totp, mpin):
    """Login using TOTP (Time-based One-Time Password)"""
    try:
        print("🔐 Attempting TOTP login...")
        
        # Step 1: TOTP Login
        totp_response = client.totp_login(
            mobile_number=mobile_number,
            ucc=ucc,
            totp=totp
        )
        print("✅ TOTP login successful!")
        print(f"Login Response: {totp_response}")
        
        # Step 2: TOTP Validation
        validation_response = client.totp_validate(mpin=mpin)
        print("✅ TOTP validation successful!")
        print(f"Validation Response: {validation_response}")
        
        return True
        
    except Exception as e:
        print(f"❌ TOTP Login failed: {str(e)}")
        return False

# def login_with_qr(client, ucc):
#     """Login using QR code method"""
#     try:
#         print("📱 Initiating QR login...")
        
#         # Step 1: Get QR code link
#         qr_response = client.qr_code_get_link(ucc=ucc)
#         print("✅ QR code generated!")
#         print(f"QR Response: {qr_response}")
#         print("📱 Please scan the QR code with your Kotak Neo mobile app")
        
#         # Step 2: Wait for user to scan and get OTT
#         ott = input("Enter the OTT received after scanning QR code: ")
        
#         # Step 3: Generate session
#         session_response = client.qr_code_generate_session(ott=ott, ucc=ucc)
#         print("✅ QR login successful!")
#         print(f"Session Response: {session_response}")
        
#         return True
        
#     except Exception as e:
#         print(f"❌ QR Login failed: {str(e)}")
#         return False

# %%
# ============================================================================
# CELL 6: Execute Login
# ============================================================================

def execute_login():
    """Execute the login process"""
    if not client:
        print("❌ Client not initialized. Please run the initialization cell first.")
        return False
    
    print("Choose login method:")
    print("1. TOTP Login (recommended)")
    print("2. QR Code Login")
    
    choice = input("Enter your choice (1 or 2): ").strip()
    
    if choice == "1":
        # TOTP Login
        if not MOBILE_NUMBER or not UCC or not MPIN:
            print("❌ Please update your credentials in the configuration cell")
            return False
        
        totp = input("Enter TOTP from your authenticator app: ").strip()
        return login_with_totp(client, MOBILE_NUMBER, UCC, totp, MPIN)
        
    # elif choice == "2":
    #     # QR Login
    #     if not UCC:
    #         print("❌ Please update your UCC in the configuration cell")
    #         return False
        
    #     return login_with_qr(client, UCC)
    
    else:
        print("❌ Invalid choice. Please enter 1 or 2.")
        return False

# Execute login
login_success = execute_login()

if login_success:
    print("\n🎉 Login completed successfully!")
    print("You can now proceed to use other API functions.")
else:
    print("\n❌ Login failed. Please check your credentials and try again.")
# Out:
# Choose login method:
# 1. TOTP Login (recommended)
# 2. QR Code Login
# 🔐 Attempting TOTP login...
# ✅ TOTP login successful!
# ...

# %%
# ============================================================================
# CELL 7: Get Positions
# ============================================================================

def get_positions():
    """Retrieve current positions"""
    try:
        print("📊 Fetching current positions...")
        
        positions = client.positions()
        
        if positions:
            print("✅ Positions retrieved successfully!")
            
            # Convert to DataFrame for better visualization
            if isinstance(positions, dict) and 'data' in positions:
                positions_data = positions['data']
            else:
                positions_data = positions
            
            if positions_data:
                df = pd.DataFrame(positions_data)
                print(f"\n📈 Total Positions: {len(df)}")
                print("\n" + "="*80)
                print("CURRENT POSITIONS")
                print("="*80)
                
                # Display key columns
                display_columns = ['trading_symbol', 'exchange_segment', 'product', 
                                 'quantity', 'average_price', 'last_price', 'pnl', 'day_change']
                
                available_columns = [col for col in display_columns if col in df.columns]
                
                if available_columns:
                    print(df[available_columns].to_string(index=False))
                else:
                    print(df.to_string(index=False))
                
                return df
            else:
                print("📊 No positions found.")
                return pd.DataFrame()
        else:
            print("❌ Failed to retrieve positions.")
            return None
            
    except Exception as e:
        print(f"❌ Error fetching positions: {str(e)}")
        return None

# Execute get positions
if login_success:
    positions_df = get_positions()
else:
    print("❌ Please login first to fetch positions.")
# Out:
# 📊 Fetching current positions...
# ✅ Positions retrieved successfully!
#
# 📈 Total Positions: 20
#
# ...
# CURRENT POSITIONS
# ...
# actId  brdLtQty  cfBuyAmt cfSellAmt cfBuyQty cfSellQty  exSeg     buyAmt sellAmt flBuyQty flSellQty prod series    tok               trdSym optTp   stkPrc   type        sym sqrFlg posFlg lotSz multiplier precision prcNum prcDen              hsUpTm        expDt        exp genNum genDen dscQty upldPrc           updRecvTm
# ZHZ3J       400      0.00      0.00        0         0 nse_fo  541440.00    0.00      400         0 NRML     XX  57034     KPITTECH25JUNFUT    XX     0.00 FUTSTK   KPITTECH      Y   true   400          1         2      1      1 2025/06/09 09:48:06 26 Jun, 2025 1750896000      1      1           0.00 1749442686026296390
# ...

# %%
# ============================================================================
# CELL 8: Get Holdings
# ============================================================================

def get_holdings():
    """Retrieve portfolio holdings"""
    try:
        print("💼 Fetching portfolio holdings...")
        
        holdings = client.holdings()
        
        if holdings:
            print("✅ Holdings retrieved successfully!")
            
            # Convert to DataFrame
            if isinstance(holdings, dict) and 'data' in holdings:
                holdings_data = holdings['data']
            else:
                holdings_data = holdings
            
            if holdings_data:
                df = pd.DataFrame(holdings_data)
                # ts = pd.DataFrame()
                print(df.head)
                print(f"\n💰 Total Holdings: {len(df)}")
                print("\n" + "="*80)
                print("PORTFOLIO HOLDINGS")
                print("="*80)
                
                # Display key columns
                display_columns = ['trading_symbol', 'exchange_segment', 'quantity', 
                                 'average_price', 'last_price', 'pnl', 'day_change']
                
                available_columns = [col for col in display_columns if col in df.columns]
                
                if available_columns:
                    print(df[available_columns].to_string(index=False))
                else:
                    print(df.to_string(index=False))
                
                return df
            else:
                print("💼 No holdings found.")
                return pd.DataFrame()
        else:
            print("❌ Failed to retrieve holdings.")
            return None
            
    except Exception as e:
        print(f"❌ Error fetching holdings: {str(e)}")
        return None

# Execute get holdings
if login_success:
    holdings_df = get_holdings()
else:
    print("❌ Please login first to fetch holdings.")
# Out:
# 💼 Fetching portfolio holdings...
# ✅ Holdings retrieved successfully!
# <bound method NDFrame.head of    displaySymbol  averagePrice  quantity exchangeSegment exchangeIdentifier  \
# 0       SHREECEM    29810.7080         5          nse_cm               3103
# 1     ULTRACEMCO    11206.3070        20          nse_cm              11532
# 2     HDFCSML250      154.5099       650          nse_cm              14233
# 3       FMCGIETF       58.8460      8150          nse_cm               5306
# 4     HEALTHIETF      137.7390      2059          nse_cm               3626
# 5     NEXT50IETF       70.9560      1400          nse_cm               4529
# 6          ITETF       41.5981     11487          nse_cm              19633
# 7         MON100      180.4242      1700          nse_cm              22739
# 8         MONQ50       80.9861      3850          nse_cm               7422
# 9     CONSUMBEES      122.3756      2082          nse_cm               2435
# ...

# %%
# ============================================================================
# STEP 8: Get Positions Data
# ============================================================================

def get_positions():
    """Fetch current positions from your trading account"""
    try:
        print("📊 Fetching positions data...")
        
        # Get positions
        positions_response = client.positions()
        
        if positions_response and 'data' in positions_response:
            positions_data = positions_response['data']
            
            print(f"✅ Successfully retrieved {len(positions_data)} positions")
            
            # Convert to DataFrame for better visualization
            if positions_data:
                df_positions = pd.DataFrame(positions_data)
                
                # Display key columns if they exist
                key_columns = ['tradingsymbol', 'exchange', 'product', 'quantity', 
                             'averageprice', 'ltp', 'pnl', 'unrealised']
                available_columns = [col for col in key_columns if col in df_positions.columns]
                
                if available_columns:
                    print("\n📋 Positions Summary:")
                    print(df_positions[available_columns].to_string(index=False))
                else:
                    print("\n📋 All Positions Data:")
                    print(df_positions.to_string(index=False))
                
                return positions_response
            else:
                print("📊 No positions found in your account")
                return positions_response
        else:
            print("❌ No position data received")
            return None
            
    except Exception as e:
        print(f"❌ Failed to fetch positions: {str(e)}")
        return None

# Function to display positions in a formatted way
def display_positions_summary(positions_response):
    """Display positions in a user-friendly format"""
    if not positions_response or 'data' not in positions_response:
        print("❌ No positions data to display")
        return
    
    positions = positions_response['data']
    
    if not positions:
        print("📊 No open positions found")
        return
    
    print("\n" + "="*80)
    print("📊 POSITIONS SUMMARY")
    print("="*80)
    
    total_pnl = 0
    
    for i, position in enumerate(positions, 1):
        print(f"\n📈 Position #{i}")
        print(f"   Symbol: {position.get('tradingsymbol', 'N/A')}")
        print(f"   Exchange: {position.get('exchange', 'N/A')}")
        print(f"   Product: {position.get('product', 'N/A')}")
        print(f"   Quantity: {position.get('quantity', 'N/A')}")
        print(f"   Avg Price: ₹{position.get('averageprice', 0)}")
        print(f"   LTP: ₹{position.get('ltp', 0)}")
        print(f"   P&L: ₹{position.get('pnl', 0)}")
        print(f"   Unrealized P&L: ₹{position.get('unrealised', 0)}")
        
        # Add to total P&L if available
        if position.get('pnl'):
            total_pnl += float(position.get('pnl', 0))
    
    print(f"\n💰 Total P&L: ₹{total_pnl:.2f}")
    print("="*80)

# Uncomment the line below after successful login to fetch positions
# positions_data = get_positions()

print("⏳ Ready to fetch positions after successful login")
# Out:
# ⏳ Ready to fetch positions after successful login

# %%
# get_positions()

# %%
# ============================================================================
# STEP 9: Additional Portfolio Information
# ============================================================================

def get_portfolio_summary():
    """Get comprehensive portfolio information"""
    try:
        print("📊 Fetching portfolio summary...")
        
        # Get positions
        positions = client.positions()
        
        # Get holdings
        holdings = client.holdings()
        
        # Get limits
        limits = client.limits()
        
        print("✅ Portfolio data fetched successfully!")
        
        # Display summary
        print("\n" + "="*60)
        print("📊 PORTFOLIO OVERVIEW")
        print("="*60)
        
        if positions and 'data' in positions:
            print(f"📈 Open Positions: {len(positions['data'])}")
        
        if holdings and 'data' in holdings:
            print(f"🏦 Holdings: {len(holdings['data'])}")
            
        if limits:
            print(f"💰 Account Limits: Available")
        
        return {
            'positions': positions,
            'holdings': holdings,
            'limits': limits
        }
        
    except Exception as e:
        print(f"❌ Failed to fetch portfolio summary: {str(e)}")
        return None

# %%
get_portfolio_summary()
# Out:
# 📊 Fetching portfolio summary...
# ✅ Portfolio data fetched successfully!
#
# ...
# 📊 PORTFOLIO OVERVIEW
# ...
# 📈 Open Positions: 20
# 🏦 Holdings: 15
# 💰 Account Limits: Available
# {'positions': {'stat': 'ok',
#   'stCode': 200,
#   'data': [{'actId': 'ZHZ3J',
#     'brdLtQty': 75,
#     'cfBuyAmt': '0.00',
#     'cfSellAmt': '0.00',
#     'cfBuyQty': '0',
#     'cfSellQty': '0',
#     'exSeg': 'nse_fo',
#     'buyAmt': '1887480.00',
#     'sellAmt': '0.00',
#     'flBuyQty': '75',
#     'flSellQty': '0',
#     'prod': 'NRML',
#     'series': 'XX',
#     'tok': '56785',
#     'trdSym': 'NIFTY25JUNFUT',
#     'optTp': 'XX',
#     'stkPrc': '0.00',
#     'type': 'FUTIDX',
#     'sym': 'NIFTY',
#     'sqrFlg': 'Y',
#     'posFlg': 'true',
#     'lotSz': '75',
#     'multiplier': '1',
#     'precision': '2',
#     'prcNum': '1',
#     'prcDen': '1',
#     'hsUpTm': '2025/06/09 09:29:45',
#     'expDt': '26 Jun, 2025',
#     'exp': '1750896000',
#     'genNum': '1',
#     'genDen': '1',
# ...

# %%
# ============================================================================
# CELL 9: Search Scrip (Stock Search)
# ============================================================================

def search_stock(exchange_segment="nse_cm"):
    """Search for a stock symbol"""
    try:
        print(f"🔍 Searching for symbol: {symbol}")
        
        search_result = client.search_scrip(
            exchange_segment=exchange_segment,
            symbol=symbol,
            expiry="",
            option_type="",
            strike_price=""
        )
        
        if search_result:
            print("✅ Search completed!")
            
            # Convert to DataFrame
            if isinstance(search_result, dict) and 'data' in search_result:
                search_data = search_result['data']
            else:
                search_data = search_result
            
            if search_data:
                df = pd.DataFrame(search_data)
                print(f"\n📊 Found {len(df)} results for '{symbol}':")
                print("\n" + "="*80)
                print("SEARCH RESULTS")
                print("="*80)
                
                # Display key columns
                display_columns = ['trading_symbol', 'exchange_segment', 'instrument_token', 
                                 'lot_size', 'tick_size']
                
                available_columns = [col for col in display_columns if col in df.columns]
                
                if available_columns:
                    print(df[available_columns].to_string(index=False))
                else:
                    print(df.to_string(index=False))
                
                return df
            else:
                print(f"❌ No results found for '{symbol}'")
                return pd.DataFrame()
        else:
            print(f"❌ Search failed for '{symbol}'")
            return None
            
    except Exception as e:
        print(f"❌ Error searching for '{symbol}': {str(e)}")
        return None

# Example: Search for RELIANCE
if login_success:
    print("Example: Searching for RELIANCE...")
    reliance_data = search_stock("RELIANCE")
else:
    print("❌ Please login first to search stocks.")
# Out:
# Example: Searching for RELIANCE...
# 🔍 Searching for symbol: RELIANCE
# ✅ Search completed!
#
# 📊 Found 2 results for 'RELIANCE':
#
# ...
# SEARCH RESULTS
# ...

# %%
# ============================================================================
# CELL 10: Place Order Functions
# ============================================================================

def place_market_order(trading_symbol, quantity, transaction_type, product="CNC", 
                      exchange_segment="nse_cm"):
    
    """Place a market order"""
    try:
        print(f"📋 Placing {transaction_type} market order for {quantity} shares of {trading_symbol}")
        
        order_response = client.place_order(
            exchange_segment=exchange_segment,
            product=product,
            price="0",  # Market order - price is 0
            order_type="MKT",
            quantity=str(quantity),
            validity="DAY",
            trading_symbol=trading_symbol,
            transaction_type=transaction_type,
            amo="NO",
            disclosed_quantity="0",
            market_protection="0",
            pf="N",
            trigger_price="0",
            tag=f"API_ORDER_{datetime.now().strftime('%Y%m%d_%H%M%S')}"
        )
        
        print("✅ Market order placed successfully!")
        print(f"Order Response: {order_response}")
        
        return order_response
        
    except Exception as e:
        print(f"❌ Error placing market order: {str(e)}")
        return None

def place_limit_order(trading_symbol, quantity, price, transaction_type, 
                     product="CNC", exchange_segment="NSE"):
    """Place a limit order"""
    try:
        print(f"📋 Placing {transaction_type} limit order for {quantity} shares of {trading_symbol} at ₹{price}")
        
        order_response = client.place_order(
            exchange_segment=exchange_segment,
            product=product,
            price=str(price),
            order_type="L",
            quantity=str(quantity),
            validity="DAY",
            trading_symbol=trading_symbol,
            transaction_type=transaction_type,
            amo="NO",
            disclosed_quantity="0",
            market_protection="0",
            pf="N",
            trigger_price="0",
            tag=f"API_ORDER_{datetime.now().strftime('%Y%m%d_%H%M%S')}"
        )
        
        print("✅ Limit order placed successfully!")
        print(f"Order Response: {order_response}")
        
        return order_response
        
    except Exception as e:
        print(f"❌ Error placing limit order: {str(e)}")
        return None

def place_stop_loss_order(trading_symbol, quantity, price, trigger_price, 
                         transaction_type, product="CNC", exchange_segment="nse_cm"):
    """Place a stop loss order"""
    try:
        print(f"📋 Placing {transaction_type} stop loss order for {quantity} shares of {trading_symbol}")
        print(f"Price: ₹{price}, Trigger Price: ₹{trigger_price}")
        
        order_response = client.place_order(
            exchange_segment=exchange_segment,
            product=product,
            price=str(price),
            order_type="SL",
            quantity=str(quantity),
            validity="DAY",
            trading_symbol=trading_symbol,
            transaction_type=transaction_type,
            amo="NO",
            disclosed_quantity="0",
            market_protection="0",
            pf="N",
            trigger_price=str(trigger_price),
            tag=f"API_ORDER_{datetime.now().strftime('%Y%m%d_%H%M%S')}"
        )
        
        print("✅ Stop loss order placed successfully!")
        print(f"Order Response: {order_response}")
        
        return order_response
        
    except Exception as e:
        print(f"❌ Error placing stop loss order: {str(e)}")
        return None

# %%
place_market_order(
        trading_symbol="INFY-EQ",      # NSE symbol for Infosys
        quantity=2,                    # Buy 2 shares
        transaction_type="B",          # B = Buy
        product="CNC",                 # Cash and Carry
        exchange_segment="nse_cm"      # NSE Cash Market
    )
# Out:
# 📋 Placing B market order for 2 shares of INFY-EQ
# ✅ Market order placed successfully!
# Order Response: {'nOrdNo': '250609000417415', 'stat': 'Ok', 'stCode': 200}
# {'nOrdNo': '250609000417415', 'stat': 'Ok', 'stCode': 200}

# %%
# ============================================================================
# CELL 11: Interactive Order Placement
# ============================================================================

def interactive_order_placement():
    """Interactive order placement interface"""
    if not login_success:
        print("❌ Please login first to place orders.")
        return
    
    print("\n" + "="*60)
    print("📋 INTERACTIVE ORDER PLACEMENT")
    print("="*60)
    
    try:
        # Get order details from user
        trading_symbol = input("Enter trading symbol (e.g., RELIANCE): ").strip().upper()
        quantity = int(input("Enter quantity: "))
        
        print("\nTransaction Type:")
        print("B - Buy")
        print("S - Sell")
        transaction_type = input("Enter transaction type (B/S): ").strip().upper()
        
        print("\nOrder Type:")
        print("1. Market Order")
        print("2. Limit Order")
        print("3. Stop Loss Order")
        order_type_choice = input("Enter choice (1/2/3): ").strip()
        
        print("\nProduct Type:")
        print("CNC - Cash and Carry")
        print("MIS - Margin Intraday")
        print("NRML - Normal")
        product = input("Enter product type (CNC/MIS/NRML): ").strip().upper()
        
        print("\nExchange Segment:")
        print("nse_cm - NSE Cash Market")
        print("bse_cm - BSE Cash Market")
        exchange_segment = input("Enter exchange segment (default: nse_cm): ").strip().lower()
        if not exchange_segment:
            exchange_segment = "nse_cm"
        
        # Place order based on type
        if order_type_choice == "1":
            # Market Order
            order_response = place_market_order(
                trading_symbol, quantity, transaction_type, product, exchange_segment
            )
        elif order_type_choice == "2":
            # Limit Order
            price = float(input("Enter limit price: "))
            order_response = place_limit_order(
                trading_symbol, quantity, price, transaction_type, product, exchange_segment
            )
        elif order_type_choice == "3":
            # Stop Loss Order
            price = float(input("Enter price: "))
            trigger_price = float(input("Enter trigger price: "))
            order_response = place_stop_loss_order(
                trading_symbol, quantity, price, trigger_price, transaction_type, product, exchange_segment
            )
        else:
            print("❌ Invalid choice!")
            return
        
        if order_response:
            print("\n✅ Order placed successfully!")
            return order_response
        else:
            print("\n❌ Order placement failed!")
            return None
            
    except ValueError as e:
        print(f"❌ Input error: {str(e)}")
        return None
    except Exception as e:
        print(f"❌ Error in order placement: {str(e)}")
        return None

# Example usage - Uncomment to use interactively
# order_response = interactive_order_placement()

# %%
# interactive_order_placement()

# %%
# ============================================================================
# CELL 12: Order Management Functions
# ============================================================================

def get_order_book():
    """Get order book"""
    try:
        print("📊 Fetching order book...")
        
        orders = client.order_report()
        
        if orders:
            print("✅ Order book retrieved successfully!")
            
            # Convert to DataFrame
            if isinstance(orders, dict) and 'data' in orders:
                orders_data = orders['data']
            else:
                orders_data = orders
            
            if orders_data:
                df = pd.DataFrame(orders_data)
                print(f"\n📋 Total Orders: {len(df)}")
                print("\n" + "="*80)
                print("ORDER BOOK")
                print("="*80)
                
                # Display key columns
                display_columns = ['order_id', 'trading_symbol', 'transaction_type', 
                                 'quantity', 'price', 'order_type', 'status', 'order_time']
                
                available_columns = [col for col in display_columns if col in df.columns]
                
                if available_columns:
                    print(df[available_columns].to_string(index=False))
                else:
                    print(df.to_string(index=False))
                
                return df
            else:
                print("📋 No orders found.")
                return pd.DataFrame()
        else:
            print("❌ Failed to retrieve order book.")
            return None
            
    except Exception as e:
        print(f"❌ Error fetching order book: {str(e)}")
        return None

def cancel_order(order_id):
    """Cancel an order"""
    try:
        print(f"❌ Cancelling order {order_id}...")
        
        cancel_response = client.cancel_order(order_id)
        
        print("✅ Order cancelled successfully!")
        print(f"Cancel Response: {cancel_response}")
        
        return cancel_response
        
    except Exception as e:
        print(f"❌ Error cancelling order: {str(e)}")
        return None

# Get current order book
# if login_success:
#     # order_book_df = get_order_book()
# else:
#     print("❌ Please login first to fetch order book.")

# %%
# it is working get order book
# get_order_book()

# %%
client.order_history(order_id = "250609000417415")
# Out:
# {'data': {'stat': 'Ok',
#   'stCode': 200,
#   'data': [{'trdSym': 'INFY-EQ',
#     'prc': '0.00',
#     'qty': 2,
#     'ordSt': 'complete',
#     'trnsTp': 'B',
#     'prcTp': 'MKT',
#     'brdLtQty': 1,
#     'exch': 'NSE',
#     'exSeg': 'nse_cm',
#     'exchTmstp': '09-Jun-2025 14:46:51',
#     'expDt': 'NA',
#     'tok': '1594',
#     'nOrdNo': '250609000417415',
#     'nReqId': '1',
#     'sym': 'INFY',
#     'avgPrc': '1574.80',
#     'algId': 'NA',
#     'algCat': 'NA',
#     'algSeqNo': 'NA',
#     'trgPrc': '0.00',
#     'dclQty': '0',
#     'exchOrdId': '1100000069345531',
#     'rejRsn': '--',
#     'ordDur': 'DAY',
#     'prod': 'CNC',
#     'rptTp': 'NA',
#     'cstFrm': 'C',
#     'ordSrc': 'ADMINCPPAPI_TRADEAPI',
#     'flDtTm': '09-Jun-2025 14:46:51',
#     'ordGenTp': '--',
#     'scripName': 'INFY',
#     'stkPrc': '0.00',
#     'legOrdInd': 'NA',
#     'fldQty': 2,
#     'ordUsrMsg': 'NA',
#     'mfdBy': 'XX',
#     'unFldSz': 0,
#     'vendorCode': '',
# ...

# %%
client.modify_order(order_id = "250609000417415", price = "", quantity = "", trigger_price = "", validity = "", order_type = "", amo = "")

# %%
client.holdings()
# Out:
# {'data': [{'displaySymbol': 'SHREECEM',
#    'averagePrice': 29810.708,
#    'quantity': 5,
#    'exchangeSegment': 'nse_cm',
#    'exchangeIdentifier': '3103',
#    'holdingCost': 149053.54,
#    'mktValue': 148000,
#    'scripId': 'd1cf5c3eef05035be939855e0be293195163749a',
#    'instrumentToken': 1926,
#    'instrumentType': 'Equity',
#    'isAlternateScrip': False,
#    'closingPrice': 29600,
#    'symbol': 'SHREECEM',
#    'instrumentName': 'Shree Cement Ltd',
#    'sector': 'Cement - Major - North India',
#    'sellableQuantity': 5,
#    'securityType': 'EQUITY STOCK',
#    'securitySubType': 'EQUITY STOCK'},
#   {'displaySymbol': 'ULTRACEMCO',
#    'averagePrice': 11206.307,
#    'quantity': 20,
#    'exchangeSegment': 'nse_cm',
#    'exchangeIdentifier': '11532',
#    'holdingCost': 224126.14,
#    'mktValue': 225060,
#    'scripId': '84c9938bb46d335c6e3e72b340ebd5090e3770f0',
#    'instrumentToken': 4104,
#    'instrumentType': 'Equity',
#    'isAlternateScrip': False,
# ...

# %%
client.limits(segment="ALL", exchange="ALL",product="ALL")
# Out:
# {'Category': 'CLIENT_MTF',
#  'EntityId': 'account-ZHZ3J',
#  'BoardLotLimit': '10000',
#  'CollateralValue': '548684.81',
#  'Collateral': '726926.32',
#  'RmsCollateral': '0',
#  'AdhocMargin': '22341.8',
#  'NotionalCash': '0',
#  'CdsSpreadBenefit': '0',
#  'AmountUtilizedPrsnt': '0',
#  'UnrealizedMtomPrsnt': '0',
#  'RealizedMtomPrsnt': '-1792',
#  'ExposureMarginPrsnt': '132708.225',
#  'SpanMarginPrsnt': '711861',
#  'NfospreadBenefit': '0',
#  'PremiumPrsnt': '17531.25',
#  'MarginVarPrsnt': '0',
#  'MarginScripBasketPrsnt': '594843.9527',
#  'MtomWarningPrcntPrsnt': '0',
#  'MarginWarningPrcntPrsnt': '97.142734',
#  'MtomSquareOffWarningPrcntPrsnt': '0',
#  'MarginUsed': '1456944.4277',
#  'RmsPayInAmt': '200000',
#  'RmsPayOutAmt': '0',
#  'Net': '41008.502300000284',
#  'SpecialMarginPrsnt': '0',
#  'DaneLimit': '0',
#  'DeliveryMarginPresent': '0',
#  'CncSellcrdPresent': '0',
#  'CollateralValueMult': '0',
#  'AdhocLimitMult': '0',
#  'RmsCollateralMult': '0',
# ...

# %%
client.scrip_master()
# Out:
# {'filesPaths': ['https://lapi.kotaksecurities.com/wso2-scripmaster/v1/prod/2025-06-09/transformed/cde_fo.csv',
#   'https://lapi.kotaksecurities.com/wso2-scripmaster/v1/prod/2025-06-09/transformed/mcx_fo.csv',
#   'https://lapi.kotaksecurities.com/wso2-scripmaster/v1/prod/2025-06-09/transformed/nse_fo.csv',
#   'https://lapi.kotaksecurities.com/wso2-scripmaster/v1/prod/2025-06-09/transformed/bse_fo.csv',
#   'https://lapi.kotaksecurities.com/wso2-scripmaster/v1/prod/2025-06-09/transformed/nse_com.csv',
#   'https://lapi.kotaksecurities.com/wso2-scripmaster/v1/prod/2025-06-09/transformed-v1/bse_cm-v1.csv',
#   'https://lapi.kotaksecurities.com/wso2-scripmaster/v1/prod/2025-06-09/transformed-v1/nse_cm-v1.csv'],
#  'baseFolder': 'https://lapi.kotaksecurities.com/wso2-scripmaster/v1/prod'}

# %%
client.trade_report()
# Out:
# {'stat': 'ok',
#  'stCode': 200,
#  'data': [{'actId': 'ZHZ3J',
#    'algCat': 'NA',
#    'algId': 'NA',
#    'avgPrc': '1574.80',
#    'boeSec': 1749460611,
#    'brdLtQty': 1,
#    'brkClnt': 'NA',
#    'cstFrm': 'C',
#    'exOrdId': '1100000069345531',
#    'exp': '-',
#    'expDt': 'NA',
#    'exSeg': 'nse_cm',
#    'exTm': '09-Jun-2025 14:46:51',
#    'fldQty': 2,
#    'flDt': '09-Jun-2025',
#    'flId': '209065008',
#    'flLeg': 1,
#    'flTm': '14:46:51',
#    'minQty': 0,
#    'nOrdNo': '250609000417415',
#    'nReqId': '1',
#    'optTp': '- ',
#    'ordDur': 'NA',
#    'ordGenTp': '--',
#    'prcTp': 'MKT',
#    'prod': 'CNC',
#    'rmk': '--',
#    'rptTp': 'fill',
#    'series': 'EQ',
#    'stkPrc': '0.00',
#    'sym': 'INFY',
#    'trdSym': 'INFY-EQ',
#    'trnsTp': 'B',
#    'usrId': 'ABDPK2569E',
#    'genDen': '1',
#    'genNum': '1',
#    'hsUpTm': '2025/06/09 14:46:51',
#    'GuiOrdId': 'API_ORDER_20250609_144652',
#    'locId': '111111111111100',
# ...

# %%
# ============================================================================
# CELL 13: Account Information
# ============================================================================

def get_account_limits():
    """Get account limits"""
    try:
        print("💰 Fetching account limits...")
        
        limits = client.limits(segment="ALL", exchange="ALL", product="ALL")
        
        if limits:
            print("✅ Account limits retrieved successfully!")
            print(f"Limits: {json.dumps(limits, indent=2)}")
            return limits
        else:
            print("❌ Failed to retrieve account limits.")
            return None
            
    except Exception as e:
        print(f"❌ Error fetching account limits: {str(e)}")
        return None

def get_trade_book():
    """Get trade book"""
    try:
        print("📈 Fetching trade book...")
        
        trades = client.trade_report()
        
        if trades:
            print("✅ Trade book retrieved successfully!")
            
            # Convert to DataFrame
            if isinstance(trades, dict) and 'data' in trades:
                trades_data = trades['data']
            else:
                trades_data = trades
            
            if trades_data:
                df = pd.DataFrame(trades_data)
                print(f"\n📊 Total Trades: {len(df)}")
                print("\n" + "="*80)
                print("TRADE BOOK")
                print("="*80)
                
                # Display key columns
                display_columns = ['trade_id', 'trading_symbol', 'transaction_type', 
                                 'quantity', 'price', 'trade_time']
                
                available_columns = [col for col in display_columns if col in df.columns]
                
                if available_columns:
                    print(df[available_columns].to_string(index=False))
                else:
                    print(df.to_string(index=False))
                
                return df
            else:
                print("📈 No trades found.")
                return pd.DataFrame()
        else:
            print("❌ Failed to retrieve trade book.")
            return None
            
    except Exception as e:
        print(f"❌ Error fetching trade book: {str(e)}")
        return None

# Get account information
if login_success:
    print("Getting account information...")
    limits = get_account_limits()
    trade_book_df = get_trade_book()
else:
    print("❌ Please login first to fetch account information.")
# Out:
# Getting account information...
# 💰 Fetching account limits...
# ✅ Account limits retrieved successfully!
# Limits: {
#   "Category": "CLIENT_MTF",
#   "EntityId": "account-ZHZ3J",
#   "BoardLotLimit": "10000",
#   "CollateralValue": "548684.81",
#   "Collateral": "726926.32",
#   "RmsCollateral": "0",
#   "AdhocMargin": "22341.8",
#   "NotionalCash": "0",
#   "CdsSpreadBenefit": "0",
#   "AmountUtilizedPrsnt": "0",
#   "UnrealizedMtomPrsnt": "11022",
#   "RealizedMtomPrsnt": "0",
#   "ExposureMarginPrsnt": "134140.225",
#   "SpanMarginPrsnt": "717000",
#   "NfospreadBenefit": "0",
#   "PremiumPrsnt": "17531.25",
#   "MarginVarPrsnt": "0",
#   "MarginScripBasketPrsnt": "591694.3527",
#   "MtomWarningPrcntPrsnt": "0.744518",
#   "MarginWarningPrcntPrsnt": "98.226573",
#   "MtomSquareOffWarningPrcntPrsnt": "0.744518",
#   "MarginUsed": "1471387.8277",
#   "RmsPayInAmt": "200000",
#   "RmsPayOutAmt": "0",
#   "Net": "26565.102300000144",
#   "SpecialMarginPrsnt": "0",
# ...

# %%
# ============================================================================
# CELL 14: Utility Functions
# ============================================================================

def get_market_quotes(trading_symbol, exchange_segment="nse_cm"):
    """Get market quotes for a symbol"""
    try:
        # First search for the instrument token
        search_result = client.search_scrip(
            exchange_segment=exchange_segment,
            symbol=trading_symbol,
            expiry="",
            option_type="",
            strike_price=""
        )
        
        if not search_result or not search_result.get('data'):
            print(f"❌ Symbol '{trading_symbol}' not found")
            return None
        
        # Get the first matching result
        instrument_data = search_result['data'][0]
        instrument_token = instrument_data['instrument_token']
        
        print(f"📊 Getting quotes for {trading_symbol}...")
        
        instrument_tokens = [{
            "instrument_token": instrument_token,
            "exchange_segment": exchange_segment
        }]
        
        quotes = client.quotes(instrument_tokens=instrument_tokens, quote_type="all")
        
        if quotes:
            print("✅ Quotes retrieved successfully!")
            print(f"Quotes: {json.dumps(quotes, indent=2)}")
            return quotes
        else:
            print("❌ Failed to retrieve quotes.")
            return None
            
    except Exception as e:
        print(f"❌ Error fetching quotes: {str(e)}")
        return None

# def logout():
#     """Logout from the session"""
#     try:
#         print("👋 Logging out...")
#         logout_response = client.logout()
#         print("✅ Logged out successfully!")
#         print(f"Logout Response: {logout_response}")
#         return logout_response
#     except Exception as e:
#         print(f"❌ Error during logout: {str(e)}")
#         return None

# %%
# ============================================================================
# CELL 15: Example Usage and Testing
# ============================================================================

def run_complete_example():
    """Run a complete example workflow"""
    if not login_success:
        print("❌ Please login first to run the complete example.")
        return
    
    print("\n" + "="*80)
    print("🚀 RUNNING COMPLETE EXAMPLE WORKFLOW")
    print("="*80)
    
    # 1. Get account information
    print("\n1️⃣ Getting account information...")
    limits = get_account_limits()
    
    # 2. Get current positions
    print("\n2️⃣ Getting current positions...")
    positions = get_positions()
    
    # 3. Get holdings
    print("\n3️⃣ Getting portfolio holdings...")
    holdings = get_holdings()
    
    # 4. Search for a stock
    print("\n4️⃣ Searching for RELIANCE...")
    stock_data = search_stock("RELIANCE")
    
    # 5. Get market quotes
    print("\n5️⃣ Getting market quotes for RELIANCE...")
    quotes = get_market_quotes("RELIANCE")
    
    # 6. Get order book
    print("\n6️⃣ Getting order book...")
    orders = get_order_book()
    
    # 7. Get trade book
    print("\n7️⃣ Getting trade book...")
    trades = get_trade_book()
    
    print("\n✅ Complete example workflow finished!")
    print("You can now use the individual functions to place orders or manage your portfolio.")

# Uncomment to run the complete example
# run_complete_example()

# %%
# ============================================================================
# CELL 16: Summary and Instructions
# ============================================================================

print("\n" + "="*80)
print("📋 KOTAK NEO API INTEGRATION SUMMARY")
print("="*80)
print("""
✅ SETUP COMPLETE! 

🔧 AVAILABLE FUNCTIONS:
- login_with_totp(): Login using TOTP
- login_with_qr(): Login using QR code
- get_positions(): Get current positions
- get_holdings(): Get portfolio holdings
- search_stock(): Search for stocks
- place_market_order(): Place market orders
- place_limit_order(): Place limit orders
- place_stop_loss_order(): Place stop loss orders
- get_order_book(): Get order history
- get_trade_book(): Get trade history
- get_account_limits(): Get account limits
- get_market_quotes(): Get live market quotes
- cancel_order(): Cancel orders
- logout(): Logout from session

📝 NEXT STEPS:
1. Update your credentials in CELL 3
2. Run the login cell (CELL 6)
3. Use the functions as needed for trading

⚠️ IMPORTANT NOTES:
- Always test with small quantities first
- Use 'uat' environment for testing
- Keep your credentials secure
- Monitor your trades regularly

📚 DOCUMENTATION:
- GitHub: https://github.com/Kotak-Neo/Kotak-neo-api-v2
- API Portal: https://www.kotaksecurities.com/platform/kotak-neo-trade-api/
""")

# Display current status
if login_success:
    print("🟢 STATUS: Logged in and ready to trade!")
else:
    print("🔴 STATUS: Please complete login to start trading.")

print("="*80)
# Out:
# ...
# 📋 KOTAK NEO API INTEGRATION SUMMARY
# ...
#
# ✅ SETUP COMPLETE!
#
# 🔧 AVAILABLE FUNCTIONS:
# - login_with_totp(): Login using TOTP
# - login_with_qr(): Login using QR code
# - get_positions(): Get current positions
# - get_holdings(): Get portfolio holdings
# - search_stock(): Search for stocks
# - place_market_order(): Place market orders
# - place_limit_order(): Place limit orders
# - place_stop_loss_order(): Place stop loss orders
# - get_order_book(): Get order history
# - get_trade_book(): Get trade history
# - get_account_limits(): Get account limits
# - get_market_quotes(): Get live market quotes
# - cancel_order(): Cancel orders
# - logout(): Logout from session
#
# 📝 NEXT STEPS:
# 1. Update your credentials in CELL 3
# 2. Run the login cell (CELL 6)
# 3. Use the functions as needed for trading
#
# ⚠️ IMPORTANT NOTES:
# - Always test with small quantities first
# - Use 'uat' environment for testing
# - Keep your credentials secure
# - Monitor your trades regularly
#
# ...
